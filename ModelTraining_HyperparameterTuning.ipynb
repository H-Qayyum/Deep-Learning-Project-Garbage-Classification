# %% [markdown]
# <a href="https://colab.research.google.com/github/H-Qayyum/Deep-Learning-Project-Garbage-Classification/blob/main/ModelTraining_HyperparameterTuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import time
import os
import numpy as np
import torch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data.sampler import SubsetRandomSampler
from sklearn.model_selection import train_test_split
from imutils import paths
import shutil
import torchvision
from torchvision import datasets, models, transforms
from collections import defaultdict
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import math

# %%
drive.mount('/content/gdrive', force_remount=False)
# Out:
# Mounted at /content/gdrive

# %%
os.makedirs('/root/dataset')
# !unzip '/content/gdrive/My Drive/Third Year/APS360/balanced_dataset/FinalDataset_balanced.zip' -d '/root/dataset'

# %%
classes = ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

dataset_path = '/root/dataset'
class_counts = defaultdict(int)

for className in classes:
    class_folder = os.path.join(dataset_path, className)
    if not os.path.isdir(class_folder):
        continue  # Skip if it's not a directory
    num_images = len([f for f in os.listdir(class_folder) if f.endswith(('.jpg', '.jpeg', '.png', '.ppm', '.bmp', '.pgm', '.tif', '.tiff', '.webp'))])
    class_counts[className] = num_images
    print(f"Number of images in class {className}: {num_images}")


data_transform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.ToTensor()
])

data = datasets.ImageFolder(dataset_path, transform=data_transform)
train_size = int(0.7 * len(data))
val_size = int(0.15 * len(data))
test_size = len(data) - train_size - val_size

train_dataset, val_dataset, test_dataset= torch.utils.data.random_split(data, [train_size, val_size, test_size])
print()
print("Size of the training dataset is:", len(train_dataset), "images")
print("Size of the validation dataset is:", len(val_dataset), "images")
print("Size of the testing dataset is:", len(test_dataset), "images")
# Out:
# Number of images in class cardboard: 3075
# Number of images in class glass: 3075
# Number of images in class metal: 3075
# Number of images in class paper: 3074
# Number of images in class plastic: 3075
# Number of images in class trash: 3075
#
# Size of the training dataset is: 12914 images
# Size of the validation dataset is: 2767 images
# Size of the testing dataset is: 2768 images

# %%
# helper functions
def get_model_name(name, batch_size, learning_rate, epoch):
    path = "model_{0}_bs{1}_lr{2}_epoch{3}".format(name, batch_size, learning_rate, epoch)
    return path

# %%
def test_model(model, test_loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in test_loader:
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    accuracy = correct / total
    return accuracy

# %%
# confusion Matrix!!!
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import torch


    # Assuming you have your test dataset and model ready
def confusionMatrix(model, data):
    model.eval()
    true_labels = []
    predicted_labels = []

    # Iterate over the test dataset to get predictions
    for inputs, labels in data:
        outputs = model(inputs)               # Forward pass
        _, predicted = torch.max(outputs, 1)        # Get the predicted class
        true_labels.extend(labels.numpy())          # Convert labels tensor to numpy array and append
        predicted_labels.extend(predicted.numpy())  # Convert predicted tensor to numpy array and append

    # Calculate and print confusion matrix
    conf_matrix = confusion_matrix(true_labels, predicted_labels)
    # Define class labels (optional)
    class_names = ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']  # Replace with your class names

    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.set(font_scale=1.2)  # Adjust font size

    # Create a heatmap with annotations and color bar
    sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='d', xticklabels=class_names, yticklabels=class_names)

    # Add labels and title
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    plt.title('Confusion Matrix')

'''
    # Show the plot
    plt.show()
    print("Confusion Matrix:")
    print(conf_matrix)
'''
# Out:
# '\n    # Show the plot\n    plt.show()\n    print("Confusion Matrix:")\n    print(conf_matrix)\n'

# %%
def train_and_eval_res(model, training_feature, validation_feature, batch_size=64, lr=0.001, epochs=30, visualize=True):

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr)
    torch.manual_seed(1000)

    iterations = []
    training_loss = []
    validation_loss = []
    training_accuracy = []
    validation_accuracy = []

    start_time = time.time()
    x = 0

    for epoch in range(epochs):

        running_train_loss = 0.0
        correct_train = 0
        total_train = 0

        for images, labels in training_feature:
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

           # Update training loss and accuracy
            running_train_loss += loss.item()
            _, predicted_train = torch.max(outputs, 1)
            total_train += labels.size(0)
            correct_train += (predicted_train == labels).sum().item()

        train_accuracy = correct_train / total_train
        avg_train_loss = running_train_loss / len(training_feature)
        training_loss.append(avg_train_loss)
        training_accuracy.append(train_accuracy)


      # Validation loop
        model.eval()
        running_val_loss = 0.0
        correct_val = 0
        total_val = 0

        with torch.no_grad():
            for images, labels in validation_feature:
                outputs = model(images)
                loss = criterion(outputs, labels)

                running_val_loss += loss.item()
                _, predicted_val = torch.max(outputs, 1)
                total_val += labels.size(0)
                correct_val += (predicted_val == labels).sum().item()

        val_accuracy = correct_val / total_val
        avg_val_loss = running_val_loss / len(validation_feature)
        validation_loss.append(avg_val_loss)
        validation_accuracy.append(val_accuracy)


        iterations.append(epoch + 1)
        print(f"Epoch {epoch + 1}: Training accuracy: {training_accuracy[-1]:.5f} | Validation accuracy: {validation_accuracy[-1]:.5f}")

        x+=1
        if x % 5 == 0:
          model_path = get_model_name(model.name, batch_size, lr, x)
          torch.save(model.state_dict(), model_path)

    end_time = time.time()
    total_time = end_time - start_time

    print(f"Total Time: {total_time:.3f} seconds")

    if visualize:
        plt.figure(figsize=(12, 6))
        plt.subplot(1, 2, 1)
        plt.title("Training Loss Curve")
        plt.plot(iterations, training_loss, label="Train")
        plt.plot(iterations, validation_loss, label='Validation')
        plt.xlabel("Epochs")
        plt.ylabel("Loss")
        plt.legend(loc='best')

        plt.subplot(1, 2, 2)
        plt.title("Training and Validation Accuracy")
        plt.plot(iterations, training_accuracy, label="Train")
        plt.plot(iterations, validation_accuracy, label="Validation")
        plt.xlabel("Epochs")
        plt.ylabel("Accuracy")
        plt.legend(loc='best')

        plt.tight_layout()
        plt.show()

# %% [markdown]
# ## ResNet 18

# %%
class resnet18_cnn(nn.Module):
    def __init__(self):
        super(resnet18_cnn, self).__init__()
        self.name = "resnet18_cnn"

        # Define the convolutional layers
        self.conv1 = nn.Conv2d(in_channels=512, out_channels=256, kernel_size=3, padding = 1)

         # Define the max pooling layer
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)   #stride will reduce the resolution by half

         # Define the linear layers
        self.fc1 = nn.Linear(in_features=256 * 3 * 3, out_features=32)
        self.fc2 = nn.Linear(in_features=32, out_features=6)     #transformation to output size of 6 for 6 garbage classes

    def forward(self, x):
        # Apply first convolution, followed by ReLU activation and max pooling
        x = self.pool(F.relu(self.conv1(x)))

        # Flatten the output of the convolutional layers
        x = torch.flatten(x, 1)

        # Apply ReLU activation to the first linear layer
        x = F.relu(self.fc1(x))

        # Apply the second linear layer
        x = self.fc2(x)

        return x

# %%
# Load pre-trained ResNet-50 model
resnet18 = models.resnet18(pretrained=True)

#remove fully connected layers from the end
resnet18 = torch.nn.Sequential(*list(resnet18.children())[:-2])

# Print the model architecture
print(resnet18)

# %%
train_dataset_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128)
val_dataset_loader = DataLoader(val_dataset, batch_size=128)
test_dataset_loader = DataLoader(test_dataset, batch_size=128)

# Initialize lists for the features
train_features_resnet18 = []
val_features_resnet18 = []
test_features_resnet18 = []

# Calculate features for the three datasets and store them
for images, labels in train_dataset_loader:
    features = resnet18(images)
    train_features_resnet18.append([torch.from_numpy(features.detach().numpy()), labels])

for images, labels in val_dataset_loader:
    features = resnet18(images)
    val_features_resnet18.append([torch.from_numpy(features.detach().numpy()), labels])

for images, labels in test_dataset_loader:
    features = resnet18(images)
    test_features_resnet18.append([torch.from_numpy(features.detach().numpy()), labels])

# %%
for features, labels in train_features_resnet18:
    print(features.shape)

# %%
print(len(train_features_resnet18))
# Out:
# 101

# %%
# Set model and train
resnet18_model = resnet18_cnn()
train_and_eval_res(resnet18_model, train_features_resnet18, val_features_resnet18, batch_size=128, lr=0.001, epochs = 30, visualize=True)
# Out:
# Epoch 1: Training accuracy: 0.56249 | Validation accuracy: 0.69462
# Epoch 2: Training accuracy: 0.72154 | Validation accuracy: 0.71449
# Epoch 3: Training accuracy: 0.76754 | Validation accuracy: 0.73726
# Epoch 4: Training accuracy: 0.80409 | Validation accuracy: 0.74377
# Epoch 5: Training accuracy: 0.83499 | Validation accuracy: 0.74051
# Epoch 6: Training accuracy: 0.86077 | Validation accuracy: 0.73256
# Epoch 7: Training accuracy: 0.87254 | Validation accuracy: 0.73039
# Epoch 8: Training accuracy: 0.88509 | Validation accuracy: 0.72172
# Epoch 9: Training accuracy: 0.89229 | Validation accuracy: 0.71738
# Epoch 10: Training accuracy: 0.90321 | Validation accuracy: 0.71413
# Epoch 11: Training accuracy: 0.91087 | Validation accuracy: 0.70293
# Epoch 12: Training accuracy: 0.90723 | Validation accuracy: 0.71558
# Epoch 13: Training accuracy: 0.91443 | Validation accuracy: 0.70365
# Epoch 14: Training accuracy: 0.92868 | Validation accuracy: 0.71413
# Epoch 15: Training accuracy: 0.95145 | Validation accuracy: 0.72533
# Epoch 16: Training accuracy: 0.95780 | Validation accuracy: 0.72244
# Epoch 17: Training accuracy: 0.95617 | Validation accuracy: 0.73256
# Epoch 18: Training accuracy: 0.96988 | Validation accuracy: 0.72461
# Epoch 19: Training accuracy: 0.97847 | Validation accuracy: 0.72642
# Epoch 20: Training accuracy: 0.98219 | Validation accuracy: 0.71630
# Epoch 21: Training accuracy: 0.98575 | Validation accuracy: 0.71305
# Epoch 22: Training accuracy: 0.98606 | Validation accuracy: 0.70257
# Epoch 23: Training accuracy: 0.98831 | Validation accuracy: 0.71522
# Epoch 24: Training accuracy: 0.99001 | Validation accuracy: 0.72606
# Epoch 25: Training accuracy: 0.99233 | Validation accuracy: 0.73329
# Epoch 26: Training accuracy: 0.99497 | Validation accuracy: 0.73292
# Epoch 27: Training accuracy: 0.99853 | Validation accuracy: 0.74087
# Epoch 28: Training accuracy: 0.99946 | Validation accuracy: 0.73329
# Epoch 29: Training accuracy: 0.99946 | Validation accuracy: 0.73762
# Epoch 30: Training accuracy: 0.99969 | Validation accuracy: 0.74015
# Total Time: 190.238 seconds

# %% [markdown]
# ##ResNet 34

# %%
# Load pre-trained ResNet-50 model
resnet34 = models.resnet34(pretrained=True)

#remove fully connected layers from the end
resnet18 = torch.nn.Sequential(*list(resnet34.children())[:-2])

# Print the model architecture
print(resnet34)

# %%
train_dataset_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128)
val_dataset_loader = DataLoader(val_dataset, batch_size=128)
test_dataset_loader = DataLoader(test_dataset, batch_size=128)

# Initialize lists for the features
train_features_resnet34 = []
val_features_resnet34 = []
test_features_resnet34 = []

# Calculate features for the three datasets and store them
for images, labels in train_dataset_loader:
    features = resnet34(images)
    train_features_resnet34.append([torch.from_numpy(features.detach().numpy()), labels])

for images, labels in val_dataset_loader:
    features = resnet34(images)
    val_features_resnet34.append([torch.from_numpy(features.detach().numpy()), labels])

for images, labels in test_dataset_loader:
    features = resnet34(images)
    test_features_resnet34.append([torch.from_numpy(features.detach().numpy()), labels])

# %%
for features, labels in train_features_resnet34:
    print(features.shape)

# %%
# Set model and train
resnet34_model = resnet_cnn()
train_and_eval(resnet18_model, train_features_resnet34, batch_size=128, lr=0.01, epochs = 30, visualize=True, validation_feature = val_features_resnet34)

# %% [markdown]
# ##ResNet 50 - 3 layers

# %%
class resnet50_cnn(nn.Module):
    def __init__(self):
        super(resnet50_cnn, self).__init__()
        self.name = "resnet50_cnn"

        # Define the convolutional layers
        self.conv1 = nn.Conv2d(in_channels=2048, out_channels=256, kernel_size=3, padding = 1)

         # Define the max pooling layer
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)   #stride will reduce the resolution by half

         # Define the linear layers
        self.fc1 = nn.Linear(in_features=256 * 3 * 3, out_features=32)
        self.fc2 = nn.Linear(in_features=32, out_features=6)     #transformation to output size of 6 for 6 garbage classes

    def forward(self, x):
        # Apply first convolution, followed by ReLU activation and max pooling
        x = self.pool(F.relu(self.conv1(x)))

        # Flatten the output of the convolutional layers
        x = torch.flatten(x, 1)

        # Apply ReLU activation to the first linear layer
        x = F.relu(self.fc1(x))

        # Apply the second linear layer
        x = self.fc2(x)

        return x

# %%
# Load pre-trained ResNet-50 model
resnet50 = models.resnet50(pretrained=True)

#remove fully connected layers from the end
resnet50 = torch.nn.Sequential(*list(resnet50.children())[:-2])

# Print the model architecture
#print(resnet50)

# %%
train_dataset_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128)
val_dataset_loader = DataLoader(val_dataset, batch_size=128)
test_dataset_loader = DataLoader(test_dataset, batch_size=128)

# Initialize lists for the features
train_features_resnet50 = []
val_features_resnet50 = []
test_features_resnet50 = []

# Calculate features for the three datasets and store them
for images, labels in train_dataset_loader:
    features = resnet50(images)
    train_features_resnet50.append([torch.from_numpy(features.detach().numpy()), labels])

for images, labels in val_dataset_loader:
    features = resnet50(images)
    val_features_resnet50.append([torch.from_numpy(features.detach().numpy()), labels])

for images, labels in test_dataset_loader:
    features = resnet50(images)
    test_features_resnet50.append([torch.from_numpy(features.detach().numpy()), labels])

# %%
# Set model and train
resnet50_model = resnet50_cnn()
train_and_eval_res(resnet50_model, train_features_resnet50, val_features_resnet50, batch_size=128, lr=0.001, epochs = 30, visualize=True)
# Out:
# Epoch 1: Training accuracy: 0.49961 | Validation accuracy: 0.63029
# Epoch 2: Training accuracy: 0.68197 | Validation accuracy: 0.67763
# Epoch 3: Training accuracy: 0.74377 | Validation accuracy: 0.75027
# Epoch 4: Training accuracy: 0.79077 | Validation accuracy: 0.76437
# Epoch 5: Training accuracy: 0.81927 | Validation accuracy: 0.73943
# Epoch 6: Training accuracy: 0.83282 | Validation accuracy: 0.73329
# Epoch 7: Training accuracy: 0.85210 | Validation accuracy: 0.74521
# Epoch 8: Training accuracy: 0.87951 | Validation accuracy: 0.75678
# Epoch 9: Training accuracy: 0.89879 | Validation accuracy: 0.74232
# Epoch 10: Training accuracy: 0.90468 | Validation accuracy: 0.74991
# Epoch 11: Training accuracy: 0.90460 | Validation accuracy: 0.74485
# Epoch 12: Training accuracy: 0.92256 | Validation accuracy: 0.74015
# Epoch 13: Training accuracy: 0.95199 | Validation accuracy: 0.75352
# Epoch 14: Training accuracy: 0.95408 | Validation accuracy: 0.75316
# Epoch 15: Training accuracy: 0.95439 | Validation accuracy: 0.74449
# Epoch 16: Training accuracy: 0.97251 | Validation accuracy: 0.74413
# Epoch 17: Training accuracy: 0.98234 | Validation accuracy: 0.74485
# Epoch 18: Training accuracy: 0.98428 | Validation accuracy: 0.71377
# Epoch 19: Training accuracy: 0.98018 | Validation accuracy: 0.75750
# Epoch 20: Training accuracy: 0.98722 | Validation accuracy: 0.76473
# Epoch 21: Training accuracy: 0.99210 | Validation accuracy: 0.76220
# Epoch 22: Training accuracy: 0.99202 | Validation accuracy: 0.75569
# Epoch 23: Training accuracy: 0.99597 | Validation accuracy: 0.76111
# Epoch 24: Training accuracy: 0.99876 | Validation accuracy: 0.76364
# Epoch 25: Training accuracy: 0.99923 | Validation accuracy: 0.76617
# Epoch 26: Training accuracy: 0.99969 | Validation accuracy: 0.76617
# Epoch 27: Training accuracy: 0.99969 | Validation accuracy: 0.76762
# Epoch 28: Training accuracy: 0.99977 | Validation accuracy: 0.76762
# Epoch 29: Training accuracy: 0.99977 | Validation accuracy: 0.76906
# Epoch 30: Training accuracy: 0.99977 | Validation accuracy: 0.76870
# Total Time: 739.230 seconds

# %%
#save model to drive

# !mv /content/model_resnet50_cnn_bs128_lr0.001_epoch30 /content/gdrive/MyDrive

# %%
#get the best model

resnet50_saved = resnet50_cnn()

resnet50_saved.load_state_dict(torch.load('/content/gdrive/MyDrive/model_resnet50_cnn_bs128_lr0.001_epoch30'))
# Out:
# <All keys matched successfully>

# %%
x = test_model(resnet50_saved, test_features_resnet50)
x = x*100
print(f"The test accuracy for the ResNet50 model is: {x:.4f}%")
# Out:
# The test accuracy for the ResNet50 model is: 78.0347%

# %%
confusionMatrix(resnet50_saved, test_features_resnet50)

# %% [markdown]
# ## ResNet 50 - 8 Layers

# %% [markdown]
# ### Model Setup

# %%
class resnet50_deep_cnn(nn.Module):
    def __init__(self):
        super(resnet50_deep_cnn, self).__init__()
        self.name = "resnet50_deep"

        # Define the convolutional layers
        self.conv1 = nn.Conv2d(in_channels=2048, out_channels=256, kernel_size=3, padding=1)     # increase depth
        self.conv2 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, padding=1)     # decrease depth
        self.conv3 = nn.Conv2d(in_channels=512, out_channels=256, kernel_size=3, padding=1)     # increase depth

        # Define the max pooling layer
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        # Define the linear layers
        self.fc1 = nn.Linear(in_features=256 * 3 * 3, out_features=512)              # increase depth
        self.fc2 = nn.Linear(in_features=512, out_features=128)                      # decrease depth
        self.fc3 = nn.Linear(in_features=128, out_features=256)                        # decrease depth
        self.fc4 = nn.Linear(in_features=256, out_features=32)                          # decrease depth
        self.fc5 = nn.Linear(in_features=32, out_features=6)                           # output to 6 classes

    def forward(self, x):
        # Apply first convolution, followed by ReLU activation and max pooling
        x = self.pool(F.relu(self.conv1(x)))
        x = (F.relu(self.conv2(x)))
        x = (F.relu(self.conv3(x)))

        # Flatten the output of the convolutional layers
        x = torch.flatten(x, 1)

        # Apply ReLU activation to the first linear layer
        x = F.relu(self.fc1(x))

        # Apply the remaining linear layers
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = self.fc5(x)

        return x

# %%
# Load pre-trained ResNet-50 model
resnet50_deep = models.resnet50(pretrained=True)

#remove fully connected layers from the end
resnet50_deep = torch.nn.Sequential(*list(resnet50_deep.children())[:-2])

# Print the model architecture
#print(resnet50)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:02<00:00, 35.3MB/s]

# %%
train_dataset_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128)
val_dataset_loader = DataLoader(val_dataset, batch_size=128)
test_dataset_loader = DataLoader(test_dataset, batch_size=128)

# Initialize lists for the features
train_features_resnet50_deep = []
val_features_resnet50_deep = []
test_features_resnet50_deep = []

# Calculate features for the three datasets and store them
for images, labels in train_dataset_loader:
    features = resnet50_deep(images)
    train_features_resnet50_deep.append([torch.from_numpy(features.detach().numpy()), labels])

for images, labels in val_dataset_loader:
    features = resnet50_deep(images)
    val_features_resnet50_deep.append([torch.from_numpy(features.detach().numpy()), labels])


for images, labels in test_dataset_loader:
    features = resnet50_deep(images)
    test_features_resnet50_deep.append([torch.from_numpy(features.detach().numpy()), labels])

# %% [markdown]
# ### Hyperparameter Tuning

# %%
# Set model and train
resnet50_model_deep = resnet50_deep_cnn()
train_and_eval_res(resnet50_model_deep, train_features_resnet50_deep, val_features_resnet50_deep, batch_size=256, lr=0.001, epochs = 30, visualize=True)
# Out:
# Epoch 1: Training accuracy: 0.32376 | Validation accuracy: 0.41850
# Epoch 2: Training accuracy: 0.57635 | Validation accuracy: 0.68666
# Epoch 3: Training accuracy: 0.73238 | Validation accuracy: 0.74449
# Epoch 4: Training accuracy: 0.78287 | Validation accuracy: 0.74413
# Epoch 5: Training accuracy: 0.79735 | Validation accuracy: 0.77376
# Epoch 6: Training accuracy: 0.81206 | Validation accuracy: 0.75280
# Epoch 7: Training accuracy: 0.83963 | Validation accuracy: 0.77087
# Epoch 8: Training accuracy: 0.85597 | Validation accuracy: 0.77376
# Epoch 9: Training accuracy: 0.85721 | Validation accuracy: 0.77412
# Epoch 10: Training accuracy: 0.86139 | Validation accuracy: 0.73112
# Epoch 11: Training accuracy: 0.87502 | Validation accuracy: 0.78786
# Epoch 12: Training accuracy: 0.88214 | Validation accuracy: 0.76726
# Epoch 13: Training accuracy: 0.88238 | Validation accuracy: 0.78207
# Epoch 14: Training accuracy: 0.87874 | Validation accuracy: 0.78244
# Epoch 15: Training accuracy: 0.90081 | Validation accuracy: 0.77412
# Epoch 16: Training accuracy: 0.90166 | Validation accuracy: 0.73256
# Epoch 17: Training accuracy: 0.89902 | Validation accuracy: 0.76798
# Epoch 18: Training accuracy: 0.90297 | Validation accuracy: 0.76400
# Epoch 19: Training accuracy: 0.90305 | Validation accuracy: 0.76111
# Epoch 20: Training accuracy: 0.92117 | Validation accuracy: 0.74557
# Epoch 21: Training accuracy: 0.92373 | Validation accuracy: 0.77557
# Epoch 22: Training accuracy: 0.94076 | Validation accuracy: 0.78750
# Epoch 23: Training accuracy: 0.94618 | Validation accuracy: 0.77159
# Epoch 24: Training accuracy: 0.95098 | Validation accuracy: 0.77991
# Epoch 25: Training accuracy: 0.95865 | Validation accuracy: 0.78099
# Epoch 26: Training accuracy: 0.96322 | Validation accuracy: 0.75678
# Epoch 27: Training accuracy: 0.96415 | Validation accuracy: 0.76906
# Epoch 28: Training accuracy: 0.96771 | Validation accuracy: 0.78569
# Epoch 29: Training accuracy: 0.96848 | Validation accuracy: 0.77593
# Epoch 30: Training accuracy: 0.97212 | Validation accuracy: 0.78063
# Total Time: 893.519 seconds

# %%
#save model to drive

# !mv /content/model_resnet50_deep_bs256_lr0.001_epoch30 /content/gdrive/MyDrive

# %%
#get the best model

resnet50_deepbs256 = resnet50_deep_cnn()

resnet50_deepbs256.load_state_dict(torch.load('/content/gdrive/MyDrive/model_resnet50_deep_bs256_lr0.001_epoch30'))
# Out:
# <All keys matched successfully>

# %%
# Set model and train
resnet50_lr01 = resnet50_deep_cnn()
train_and_eval_res(resnet50_lr01, train_features_resnet50_deep, val_features_resnet50_deep, batch_size=64, lr=0.0001, epochs = 30, visualize=True)
# Out:
# Epoch 1: Training accuracy: 0.46701 | Validation accuracy: 0.62812
# Epoch 2: Training accuracy: 0.69971 | Validation accuracy: 0.72317
# Epoch 3: Training accuracy: 0.75244 | Validation accuracy: 0.74883
# Epoch 4: Training accuracy: 0.78372 | Validation accuracy: 0.76979
# Epoch 5: Training accuracy: 0.81694 | Validation accuracy: 0.77412
# Epoch 6: Training accuracy: 0.84676 | Validation accuracy: 0.77774
# Epoch 7: Training accuracy: 0.87680 | Validation accuracy: 0.76906
# Epoch 8: Training accuracy: 0.88509 | Validation accuracy: 0.77954
# Epoch 9: Training accuracy: 0.88036 | Validation accuracy: 0.77449
# Epoch 10: Training accuracy: 0.87285 | Validation accuracy: 0.78063
# Epoch 11: Training accuracy: 0.89655 | Validation accuracy: 0.78822
# Epoch 12: Training accuracy: 0.92009 | Validation accuracy: 0.79689
# Epoch 13: Training accuracy: 0.93751 | Validation accuracy: 0.79906
# Epoch 14: Training accuracy: 0.94115 | Validation accuracy: 0.79906
# Epoch 15: Training accuracy: 0.95013 | Validation accuracy: 0.79508
# Epoch 16: Training accuracy: 0.95346 | Validation accuracy: 0.80231
# Epoch 17: Training accuracy: 0.96802 | Validation accuracy: 0.78713
# Epoch 18: Training accuracy: 0.96601 | Validation accuracy: 0.77123
# Epoch 19: Training accuracy: 0.97212 | Validation accuracy: 0.75533
# Epoch 20: Training accuracy: 0.96957 | Validation accuracy: 0.74846
# Epoch 21: Training accuracy: 0.97623 | Validation accuracy: 0.79942
# Epoch 22: Training accuracy: 0.97840 | Validation accuracy: 0.79075
# Epoch 23: Training accuracy: 0.98064 | Validation accuracy: 0.79111
# Epoch 24: Training accuracy: 0.97878 | Validation accuracy: 0.78424
# Epoch 25: Training accuracy: 0.98025 | Validation accuracy: 0.79256
# Epoch 26: Training accuracy: 0.98660 | Validation accuracy: 0.80665
# Epoch 27: Training accuracy: 0.99094 | Validation accuracy: 0.80520
# Epoch 28: Training accuracy: 0.99303 | Validation accuracy: 0.79147
# Epoch 29: Training accuracy: 0.99326 | Validation accuracy: 0.79906
# Epoch 30: Training accuracy: 0.99613 | Validation accuracy: 0.80376
# Total Time: 858.811 seconds

# %%
#save model to drive

# !mv /content/model_resnet50_deep_bs64_lr0.0001_epoch30 /content/gdrive/MyDrive

# %%
#get the best model

resnet50_80percent = resnet50_deep_cnn()

resnet50_80percent.load_state_dict(torch.load('/content/gdrive/MyDrive//model_resnet50_deep_bs64_lr0.0001_epoch30'))
# Out:
# <All keys matched successfully>

# %%
# Set model and train
resnet50_deep = resnet50_deep_cnn()
train_and_eval_res(resnet50_deep, train_features_resnet50_deep, val_features_resnet50_deep, batch_size=64, lr=0.001, epochs = 35, visualize=True)
# Out:
# Epoch 1: Training accuracy: 0.29456 | Validation accuracy: 0.33719
# Epoch 2: Training accuracy: 0.44587 | Validation accuracy: 0.53704
# Epoch 3: Training accuracy: 0.56319 | Validation accuracy: 0.57463
# Epoch 4: Training accuracy: 0.62088 | Validation accuracy: 0.63318
# Epoch 5: Training accuracy: 0.66486 | Validation accuracy: 0.68558
# Epoch 6: Training accuracy: 0.74648 | Validation accuracy: 0.72642
# Epoch 7: Training accuracy: 0.78852 | Validation accuracy: 0.76328
# Epoch 8: Training accuracy: 0.81268 | Validation accuracy: 0.76798
# Epoch 9: Training accuracy: 0.82306 | Validation accuracy: 0.77051
# Epoch 10: Training accuracy: 0.82740 | Validation accuracy: 0.76184
# Epoch 11: Training accuracy: 0.84435 | Validation accuracy: 0.77087
# Epoch 12: Training accuracy: 0.84629 | Validation accuracy: 0.77521
# Epoch 13: Training accuracy: 0.85744 | Validation accuracy: 0.76653
# Epoch 14: Training accuracy: 0.85597 | Validation accuracy: 0.76509
# Epoch 15: Training accuracy: 0.86193 | Validation accuracy: 0.75099
# Epoch 16: Training accuracy: 0.87688 | Validation accuracy: 0.77629
# Epoch 17: Training accuracy: 0.87765 | Validation accuracy: 0.76220
# Epoch 18: Training accuracy: 0.87099 | Validation accuracy: 0.76328
# Epoch 19: Training accuracy: 0.88826 | Validation accuracy: 0.75750
# Epoch 20: Training accuracy: 0.88942 | Validation accuracy: 0.75750
# Epoch 21: Training accuracy: 0.90142 | Validation accuracy: 0.76256
# Epoch 22: Training accuracy: 0.90251 | Validation accuracy: 0.75425
# Epoch 23: Training accuracy: 0.90026 | Validation accuracy: 0.73654
# Epoch 24: Training accuracy: 0.89004 | Validation accuracy: 0.72244
# Epoch 25: Training accuracy: 0.91134 | Validation accuracy: 0.74774
# Epoch 26: Training accuracy: 0.91467 | Validation accuracy: 0.75280
# Epoch 27: Training accuracy: 0.91954 | Validation accuracy: 0.74630
# Epoch 28: Training accuracy: 0.92218 | Validation accuracy: 0.77232
# Epoch 29: Training accuracy: 0.94216 | Validation accuracy: 0.77087
# Epoch 30: Training accuracy: 0.94680 | Validation accuracy: 0.77123
# Epoch 31: Training accuracy: 0.94936 | Validation accuracy: 0.77196
# Epoch 32: Training accuracy: 0.95880 | Validation accuracy: 0.76256
# Epoch 33: Training accuracy: 0.96856 | Validation accuracy: 0.75352
# Epoch 34: Training accuracy: 0.97150 | Validation accuracy: 0.77015
# Epoch 35: Training accuracy: 0.97390 | Validation accuracy: 0.76328
# Total Time: 1046.914 seconds

# %% [markdown]
# ### Final Model

# %%
# Set model and train
resnet50_deep = resnet50_deep_cnn()
train_and_eval_res(resnet50_deep, train_features_resnet50_deep, val_features_resnet50_deep, batch_size=128, lr=0.0001, epochs = 50, visualize=True)
# Out:
# Epoch 1: Training accuracy: 0.45416 | Validation accuracy: 0.62739
# Epoch 2: Training accuracy: 0.68097 | Validation accuracy: 0.70473
# Epoch 3: Training accuracy: 0.74400 | Validation accuracy: 0.74304
# Epoch 4: Training accuracy: 0.78233 | Validation accuracy: 0.75425
# Epoch 5: Training accuracy: 0.81578 | Validation accuracy: 0.74991
# Epoch 6: Training accuracy: 0.84381 | Validation accuracy: 0.75714
# Epoch 7: Training accuracy: 0.85427 | Validation accuracy: 0.78677
# Epoch 8: Training accuracy: 0.85798 | Validation accuracy: 0.75678
# Epoch 9: Training accuracy: 0.89484 | Validation accuracy: 0.80882
# Epoch 10: Training accuracy: 0.91985 | Validation accuracy: 0.79978
# Epoch 11: Training accuracy: 0.93472 | Validation accuracy: 0.77015
# Epoch 12: Training accuracy: 0.92737 | Validation accuracy: 0.76979
# Epoch 13: Training accuracy: 0.92164 | Validation accuracy: 0.79436
# Epoch 14: Training accuracy: 0.92659 | Validation accuracy: 0.79003
# Epoch 15: Training accuracy: 0.93317 | Validation accuracy: 0.78388
# Epoch 16: Training accuracy: 0.94231 | Validation accuracy: 0.78135
# Epoch 17: Training accuracy: 0.94448 | Validation accuracy: 0.73581
# Epoch 18: Training accuracy: 0.95695 | Validation accuracy: 0.76184
# Epoch 19: Training accuracy: 0.96817 | Validation accuracy: 0.80304
# Epoch 20: Training accuracy: 0.97181 | Validation accuracy: 0.81352
# Epoch 21: Training accuracy: 0.97762 | Validation accuracy: 0.77232
# Epoch 22: Training accuracy: 0.97514 | Validation accuracy: 0.78750
# Epoch 23: Training accuracy: 0.98529 | Validation accuracy: 0.79761
# Epoch 24: Training accuracy: 0.98970 | Validation accuracy: 0.81424
# Epoch 25: Training accuracy: 0.99001 | Validation accuracy: 0.78497
# Epoch 26: Training accuracy: 0.98916 | Validation accuracy: 0.80412
# Epoch 27: Training accuracy: 0.98939 | Validation accuracy: 0.79834
# Epoch 28: Training accuracy: 0.98993 | Validation accuracy: 0.80557
# Epoch 29: Training accuracy: 0.98807 | Validation accuracy: 0.80557
# Epoch 30: Training accuracy: 0.98885 | Validation accuracy: 0.79472
# Epoch 31: Training accuracy: 0.99086 | Validation accuracy: 0.77738
# Epoch 32: Training accuracy: 0.98846 | Validation accuracy: 0.79581
# Epoch 33: Training accuracy: 0.99411 | Validation accuracy: 0.79292
# Epoch 34: Training accuracy: 0.99187 | Validation accuracy: 0.78930
# Epoch 35: Training accuracy: 0.99497 | Validation accuracy: 0.81749
# Epoch 36: Training accuracy: 0.99915 | Validation accuracy: 0.81496
# Epoch 37: Training accuracy: 0.99915 | Validation accuracy: 0.81207
# Epoch 38: Training accuracy: 0.99783 | Validation accuracy: 0.80701
# Epoch 39: Training accuracy: 0.99063 | Validation accuracy: 0.81279
# Epoch 40: Training accuracy: 0.99264 | Validation accuracy: 0.79689
# Epoch 41: Training accuracy: 0.99582 | Validation accuracy: 0.79508
# Epoch 42: Training accuracy: 0.99729 | Validation accuracy: 0.80593
# Epoch 43: Training accuracy: 0.99683 | Validation accuracy: 0.79075
# Epoch 44: Training accuracy: 0.99636 | Validation accuracy: 0.80340
# Epoch 45: Training accuracy: 0.99582 | Validation accuracy: 0.80231
# Epoch 46: Training accuracy: 0.99179 | Validation accuracy: 0.79725
# Epoch 47: Training accuracy: 0.99388 | Validation accuracy: 0.80051
# Epoch 48: Training accuracy: 0.99837 | Validation accuracy: 0.80267
# Epoch 49: Training accuracy: 0.99381 | Validation accuracy: 0.80448
# Epoch 50: Training accuracy: 0.99590 | Validation accuracy: 0.79292
# Total Time: 1438.713 seconds

# %%
#save model to drive

# !mv /content/model_resnet50_deep_bs128_lr0.0001_epoch35 /content/gdrive/MyDrive

# %%
#get the best model

final_model = resnet50_deep_cnn()

final_model.load_state_dict(torch.load('/content/gdrive/MyDrive/model_resnet50_deep_bs128_lr0.0001_epoch35'))
# Out:
# <All keys matched successfully>

# %%
x = test_model(final_model, test_features_resnet50_deep)
x = x*100
print(f"The test accuracy for the ResNet50 model is: {x:.4f}%")
# Out:
# The test accuracy for the ResNet50 model is: 82.2616%

# %%
confusionMatrix(final_model, val_features_resnet50_deep)

# %%
confusionMatrix(final_model, test_features_resnet50_deep)
